# %%
import requests
url = "https://www.imf.org/external/datamapper/api/v1/indicators"

results= requests.get(url).json()
df = pd.DataFrame.from_dict(results)["indicators"].apply(pd.Series)
df
# Out:
#                 0 dataset                                        description  \
# NGDP_RPCH     NaN     WEO  Gross domestic product is the most commonly us...
# NGDPD         NaN     WEO  Gross domestic product is the most commonly us...
# NGDPDPC       NaN     WEO  Gross domestic product is the most commonly us...
# PPPGDP        NaN     WEO  Gross domestic product is the most commonly us...
# PPPPC         NaN     WEO  Gross domestic product (GDP) is the most commo...
# ...            ..     ...                                                ...
# TTT           NaN  AFRREO
# FR_ind        NaN   FR_FC  Indicates whether the country has a national o...
# FC_dummy      NaN   FR_FC  FC: Fiscal councils\n<b>Note</b>: Line charts ...
# version       NaN     NaN                                                NaN
# output-method NaN     NaN                                                NaN
#
#                                             label  \
# ...

# %%
term_search = "rade"

df[df["description"].str.contains(term_search).fillna(False)]
# Out:
#         0 dataset                                        description  \
# Ka_dr NaN      CL  Derivative investment openness index captures ...
# Ka_cc NaN      CL  Commercial credit openness index captures the ...
#
#                                                    label            source  \
# Ka_dr  Derivative investment openness index (1=fully ...  Wang-Jahan Index
# Ka_cc  Commercial credit openness index (1=fully libe...  Wang-Jahan Index
#
#         unit
# Ka_dr  Units
# Ka_cc  Units

# %%
url2 = "http://dataservices.imf.org/REST/SDMX_XML.svc/Dataflow"
    
results= requests.get(url2).json()
results
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     970         try:
# --> 971             return complexjson.loads(self.text, **kwargs)
#     972         except JSONDecodeError as e:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/simplejson/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, **kw)
#     524             and not use_decimal and not kw):
# --> 525         return _default_decoder.decode(s)
#     526     if cls is None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/simplejson/decoder.py in decode(self, s, _w, _PY3)
#     369             s = str(s, self.encoding)
# --> 370         obj, end = self.raw_decode(s)
#     371         end = _w(s, end).end()
#
# ...
